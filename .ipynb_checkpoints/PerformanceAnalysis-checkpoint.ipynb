# %% [markdown]
# # Performance between Groups

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# load primary data
primaryData = pd.read_csv(r'./data/table1.csv')
primaryData = primaryData[primaryData['Experimental Status']!='Disceased']
primaryData.drop(['Age (wks)','Birth status', 'Estimated Delivery Date', 'Delivery Date', 
              'Set up', 'Ween', 'Male Status', 'Breeding Status',
              'Virus Implantation'],axis=1,inplace=True)

primaryData
# Out:
#       Mouse ID         Genotype Gender                     Line TgSWDI  \
# 0          170          Tg-SwDI      M                  Tg-SwDI    Pos
# 1          171          Tg-SwDI      M                  Tg-SwDI    Pos
# 2          224          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 3          225          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 4          233          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 5          172          Tg-SwDI      F                      NaN    Pos
# 6          173          Tg-SwDI      F                  Tg-SwDI    Pos
# 7          174          Tg-SwDI      F                  Tg-SwDI    Pos
# 8          175          Tg-SwDI      F                  Tg-SwDI    Pos
# 9          231          Tg-SwDI      F                  Tg-SwDI    Pos
# 10         254          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 11         255          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 12         260          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 13         261          Tg-SwDI      M          Tg-SwDI x ThCre    Pos
# 14         282          Tg-SwDI      F                  Tg-SwDI    Pos
# 15         284          Tg-SwDI      F                  Tg-SwDI    Pos
# 16         285          Tg-SwDI      F                  Tg-SwDI    Pos
# 17         286          Tg-SwDI      F                  Tg-SwDI    Pos
# 18         177  Tg-SwDI x ThCre      M  Tg-SwDI x (ThCre x ChR)    Pos
# 19         178  Tg-SwDI x ThCre      M  Tg-SwDI x (ThCre x ChR)    Pos
# 20         221  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 21         234  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 22         181  Tg-SwDI x ThCre      F  Tg-SwDI x (ThCre x ChR)    Pos
# 23         182  Tg-SwDI x ThCre      F  Tg-SwDI x (ThCre x ChR)    Pos
# 24         228  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 25         230  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 26         232  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 27         253  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 28         256  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 29         259  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 30         263  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 31         264  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
# 32         184  Tg-SwDI x ThCre      F  Tg-SwDI x (ThCre x ChR)    Pos
# 33         236  Tg-SwDI x ThCre      F  Tg-SwDI x (ThCre x ChR)    Pos
# 34         238  Tg-SwDI x ThCre      F  Tg-SwDI x (ThCre x ChR)    Pos
# 35         276  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 36         265  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 37         270  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 38         272  Tg-SwDI x ThCre      F          Tg-SwDI x ThCre    Pos
# 39         190            ThCre      M                    ThCre    Pos
# 40         193            ThCre      M                    ThCre    Pos
# 41         194            ThCre      M                    ThCre    Pos
# 42         196            ThCre      M                    ThCre    Pos
# 43         207            ThCre      M                    ThCre    Pos
# 44         202            ThCre      M                    ThCre    Pos
# 45         203            ThCre      M                    ThCre    Pos
# 46          71            ThCre      F          Th-Cre x DREADD    Pos
# 47          99            ThCre      F           Th-Cre x Gcamp    Pos
# 48         131            ThCre      F       Th-Cre x C57BL/6NJ    Pos
# 49         210            ThCre      F                    ThCre    Pos
# 50         211            ThCre      F                    ThCre    Pos
# 51         NaN              NaN    NaN                      NaN    NaN
# 52         NaN              NaN    NaN                      NaN    NaN
# 53  Disceased:              NaN    NaN                      NaN    NaN
# 54         116              NaN      M                  Tg-SwDI    POS
# 56         222  Tg-SwDI x ThCre      M          Tg-SwDI x ThCre    Pos
#
#    Genotype 2 Genotype 3         Father              Mother         DOB  \
# 0         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 1         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 2         Neg        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 3         Neg        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 4         Neg        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 5         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 6         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 7         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 8         NaN        NaN  Tg-SwDI (116)       Tg-SwDI (117)    8/2/2019
# 9         NaN        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 10        Neg        NaN   Tg-SwDI(116)        ThCre(71/99)   10/2/2019
# 11        Neg        NaN   Tg-SwDI(116)        ThCre(71/99)   10/2/2019
# 12        Neg        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 13        Neg        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 14        NaN        NaN   Tg-SwDI(116)                 117  10/29/2019
# 15        NaN        NaN   Tg-SwDI(116)                 117   9/15/2019
# 16        NaN        NaN   Tg-SwDI(116)                 117   9/15/2019
# 17        NaN        NaN   Tg-SwDI(116)                 117   9/15/2019
# 18        Pos        Neg  Tg-SwDI (116)    ThCre x ChR (89)    7/7/2019
# 19        Pos        Neg  Tg-SwDI (116)    ThCre x ChR (89)    7/7/2019
# 20        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 21        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 22        Pos        Neg  Tg-SwDI (116)    ThCre x ChR (89)    7/7/2019
# 23        Pos        Neg  Tg-SwDI (116)    ThCre x ChR (89)    7/7/2019
# 24        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 25        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 26        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
# 27        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   10/2/2019
# 28        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   10/2/2019
# 29        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 30        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 31        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 32        Pos        Pos  Tg-SwDI (116)    ThCre x ChR (89)    7/7/2019
# 33        Pos        Neg   Tg-SwDI(116)  Th-Cre x ChR2 (88)   8/23/2019
# 34        Pos        Neg   Tg-SwDI(116)  Th-Cre x ChR2 (88)   8/23/2019
# 35        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 36        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   10/2/2019
# 37        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 38        Pos        NaN   Tg-SwDI(116)      ThCre(210/211)  10/21/2019
# 39        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 40        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 41        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 42        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 43        NaN        NaN      ThCre (3)      C57 (43 or 44)   7/23/2019
# 44        NaN        NaN      ThCre (3)      C57 (43 or 44)   7/23/2019
# 45        NaN        NaN      ThCre (3)      C57 (43 or 44)   7/23/2019
# 46        Neg        NaN      Th-Cre(1)           DREAD(13)   3/20/2019
# 47        Neg        NaN            NaN                 NaN    5/1/2019
# 48        NaN        NaN            NaN                 NaN   7/15/2019
# 49        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 50        NaN        NaN     ThCre (58)      C57 (56 or 65)   7/18/2019
# 51        NaN        NaN            NaN                 NaN         NaN
# 52        NaN        NaN            NaN                 NaN         NaN
# 53        NaN        NaN            NaN                 NaN         NaN
# 54        NaN        NaN            Jax                 Jax         NaN
# 56        Pos        NaN   Tg-SwDI(116)        ThCre(71/99)   8/24/2019
#
#    Maze Configuration Treatment Group Experimental Status
# 0                ABFG              --             Testing
# 1                ABFG              --             Testing
# 2                ABFG              --             Testing
# 3                ABFG              --             Testing
# 4                ABFG              --             Testing
# 5                BCEG              --             Testing
# 6                BCEG              --             Testing
# 7                BCEG              --             Testing
# 8                BCEG              --             Testing
# 9                BCEG              --             Testing
# 10               BDFH            MAMP             Testing
# 11               BDFH            MAMP             Testing
# 12               BDFH            MAMP             Testing
# 13               BDFH            MAMP             Testing
# 14               ACDF            MAMP             Testing
# 15               ACDF            MAMP             Testing
# 16               ACDF            MAMP             Testing
# 17               ACDF            MAMP             Testing
# 18               ACDF   High Dose CNO             Testing
# 19               ACDF   High Dose CNO             Testing
# 20               ACDF   High Dose CNO                 NaN
# 21               ACDF   High Dose CNO                 NaN
# 22               BDFH   High Dose CNO             Testing
# 23               BDFH   High Dose CNO             Testing
# 24               BDFH   High Dose CNO             Testing
# 25               BDFH   High Dose CNO             Testing
# 26               BDFH   High Dose CNO             Testing
# 27               ABFG    Low Dose CNO                 NaN
# 28               ABFG    Low Dose CNO                 NaN
# 29               ABFG    Low Dose CNO             Testing
# 30               ABFG    Low Dose CNO                 NaN
# 31               ABFG    Low Dose CNO             Testing
# 32               BDFH    Low Dose CNO             Testing
# 33               BDFH    Low Dose CNO             Testing
# 34               BDFH    Low Dose CNO                 NaN
# 35               BDFH    Low Dose CNO                 NaN
# 36               BDFH    Low Dose CNO                 NaN
# 37               BDFH    Low Dose CNO                 NaN
# 38               BDFH    Low Dose CNO                 NaN
# 39               BCEG              --             Testing
# 40               BCEG              --             Testing
# 41               BCEG              --             Testing
# 42               BCEG              --             Testing
# 43               BCEG              --             Testing
# 44               ABFG              --             Testing
# 45               ABFG              --             Testing
# 46               ABFG              --             Testing
# 47               ABFG              --             Testing
# 48               ABFG              --             Testing
# 49               ABFG              --             Testing
# 50               ABFG              --             Testing
# 51                NaN             NaN                 NaN
# 52                NaN             NaN                 NaN
# 53                NaN             NaN                 NaN
# 54               ABFG             NaN                 NaN
# 56               ACDF   High Dose CNO                 NaN

# %%
# load experimental data
experimentalData = pd.read_csv(r'./data/table2.csv')
experimentalData = experimentalData[experimentalData['Date']>='2020-01-01']
experimentalData
# Out:
#      Mouse ID        Date  Weight  Baited Arms Retrieved  \
# 442       285  2020-01-01      25                      0
# 443        71  2020-01-01      25                      1
# 444       260  2020-01-01      28                      1
# 445       261  2020-01-01      28                      0
# 446       284  2020-01-01      22                      0
# ..        ...         ...     ...                    ...
# 944       207  2020-02-29      30                      4
# 945       202  2020-02-29      30                      4
# 946       178  2020-02-29      28                      4
# 947       211  2020-02-29      24                      4
# 948       181  2020-02-29      24                      4
#
#      Reference Memory Errors  Working Memory Errors Other Notes  \
# 442                       16                     23         NaN
# 443                       29                     53         NaN
# 444                       23                     27         NaN
# 445                       26                     46         NaN
# 446                       14                     24         NaN
# ..                       ...                    ...         ...
# 944                        3                      3         NaN
# 945                        9                     10         NaN
# 946                        5                      4         NaN
# 947                        6                      2        GABF
# 948                        4                      3         NaN
#
#               Start Time             End Time Video Length  ...      Distance  \
# 442  2020-01-01 12:31:07  2020-01-01 12:41:07      0:10:00  ...  21840.552995
# 443  2020-01-01 15:36:00  2020-01-01 15:46:00      0:10:00  ...  31366.376863
# 444  2020-01-01 13:18:12  2020-01-01 13:28:02      0:09:50  ...  16997.318591
# 445  2020-01-01 13:40:21  2020-01-01 13:49:55      0:09:34  ...  27863.110858
# 446  2020-01-01 12:08:45  2020-01-01 12:18:45      0:10:00  ...  20624.253365
# ..                   ...                  ...          ...  ...           ...
# 944  2020-02-29 15:54:14  2020-02-29 15:55:40      0:01:26  ...   4644.497932
# 945  2020-02-29 15:21:45  2020-02-29 15:28:48      0:07:03  ...  11987.690376
# 946  2020-02-29 17:49:36  2020-02-29 17:53:42      0:04:06  ...   6935.927508
# 947  2020-02-29 14:33:15  2020-02-29 14:34:35      0:01:20  ...   4191.584958
# 948  2020-02-29 19:18:11  2020-02-29 19:22:46      0:04:35  ...   6303.803784
#
#        Center      ArmA      ArmB      ArmC      ArmD      ArmE      ArmF  \
# 442  0.111185  0.080736  0.050119  0.040173  0.234928  0.191365  0.187087
# 443  0.180530  0.094627  0.126299  0.101295  0.118186  0.095016  0.057065
# 444  0.117993  0.168230  0.081657  0.080018  0.156476  0.221349  0.049051
# 445  0.216202  0.078223  0.096806  0.122706  0.142509  0.096632  0.101278
# 446  0.129188  0.178530  0.110630  0.085514  0.263933  0.028394  0.084125
# ..        ...       ...       ...       ...       ...       ...       ...
# 944  0.076744  0.087984  0.191085  0.148837  0.059302  0.188372  0.161628
# 945  0.063617  0.146051  0.168727  0.068420  0.233367  0.138572  0.025667
# 946  0.041384  0.177748  0.039213  0.014111  0.068657  0.299322  0.182632
# 947  0.086164  0.223695  0.203397  0.044739  0.099420  0.050539  0.058824
# 948  0.028364  0.157576  0.054788  0.024242  0.071879  0.355515  0.011636
#
#          ArmG      ArmH
# 442  0.046674  0.058621
# 443  0.150414  0.079069
# 444  0.050746  0.077588
# 445  0.076829  0.071661
# 446  0.051120  0.069512
# ..        ...       ...
# 944  0.086822  0.000000
# 945  0.075663  0.080545
# 946  0.066757  0.111398
# 947  0.192626  0.041839
# 948  0.000000  0.296606
#
# [507 rows x 29 columns]

# %%
# number of valid mice
allMice = list(pd.unique(primaryData['Mouse ID']))
len(allMice)
# Out:
# 55

# %% [markdown]
# ### Grouping

# %% [markdown]
# Genotype Groups:
#     1. Tg-SwDI+
#     2. Th-Cre+
#     3. Tg-SwDI+ x Th-Cre+ low dose group
#     4. Tg-SwDI+ x Th-Cre+ high dose group

# %%
# all mice under test
primaryData = primaryData[primaryData['Experimental Status']=='Testing']

# %%
class Group:
    
    def __init__(self,primaryData,experimentalData,genotype,treatment):
        
        groupPrimaryData = primaryData[primaryData['Genotype']==genotype]
        groupPrimaryData = groupPrimaryData[groupPrimaryData['Treatment Group']==treatment]
        groupPrimaryData.reset_index(drop=True,inplace=True)
        
        self.name = genotype + '(' + treatment + ')'
        self.groupPrimaryData = groupPrimaryData
        self.genotype = genotype
        self.treatment = treatment
        self.members = list(groupPrimaryData['Mouse ID'])
        self.size = len(list(groupPrimaryData['Mouse ID']))
        
        def in_group(x):
            return str(x) in self.members
        groupExperimentalData = experimentalData[experimentalData['Mouse ID'].apply(in_group)]
        groupExperimentalData.reset_index(drop=True,inplace=True)
        self.groupExperimentalData = groupExperimentalData

        
    def info(self):
        print('---------------------------------')
        print('Genotype:',self.genotype,' | Treatment:',self.treatment)
        print('Members:',self.members)
        print('Size:',self.size)
        return

# %%
group1 = Group(primaryData,experimentalData,'Tg-SwDI','--')
group2 = Group(primaryData,experimentalData,'Tg-SwDI','MAMP')
group3 = Group(primaryData,experimentalData,'Tg-SwDI x ThCre','Low Dose CNO')
group4 = Group(primaryData,experimentalData,'Tg-SwDI x ThCre','High Dose CNO')
group5 = Group(primaryData,experimentalData,'ThCre','--')

group1.groupPrimaryData
# Out:
#   Mouse ID Genotype Gender             Line TgSWDI Genotype 2 Genotype 3  \
# 0      170  Tg-SwDI      M          Tg-SwDI    Pos        NaN        NaN
# 1      171  Tg-SwDI      M          Tg-SwDI    Pos        NaN        NaN
# 2      224  Tg-SwDI      M  Tg-SwDI x ThCre    Pos        Neg        NaN
# 3      225  Tg-SwDI      M  Tg-SwDI x ThCre    Pos        Neg        NaN
# 4      233  Tg-SwDI      M  Tg-SwDI x ThCre    Pos        Neg        NaN
# 5      172  Tg-SwDI      F              NaN    Pos        NaN        NaN
# 6      173  Tg-SwDI      F          Tg-SwDI    Pos        NaN        NaN
# 7      174  Tg-SwDI      F          Tg-SwDI    Pos        NaN        NaN
# 8      175  Tg-SwDI      F          Tg-SwDI    Pos        NaN        NaN
# 9      231  Tg-SwDI      F          Tg-SwDI    Pos        NaN        NaN
#
#           Father         Mother        DOB Maze Configuration Treatment Group  \
# 0  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               ABFG              --
# 1  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               ABFG              --
# 2   Tg-SwDI(116)   ThCre(71/99)  8/24/2019               ABFG              --
# 3   Tg-SwDI(116)   ThCre(71/99)  8/24/2019               ABFG              --
# 4   Tg-SwDI(116)   ThCre(71/99)  8/24/2019               ABFG              --
# 5  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               BCEG              --
# 6  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               BCEG              --
# 7  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               BCEG              --
# 8  Tg-SwDI (116)  Tg-SwDI (117)   8/2/2019               BCEG              --
# 9   Tg-SwDI(116)   ThCre(71/99)  8/24/2019               BCEG              --
#
#   Experimental Status
# 0             Testing
# 1             Testing
# 2             Testing
# 3             Testing
# 4             Testing
# 5             Testing
# 6             Testing
# 7             Testing
# 8             Testing
# 9             Testing

# %%
class Mouse:
    
    
    def __init__(self, grouping, ID: str):
        '''
        grouping should be a list of Group objects
        '''
        self.ID = ID 
        for group in grouping:
            if ID in group.members:
                self.category = group.name 
                self.primaryData = group.groupPrimaryData[group.groupPrimaryData['Mouse ID']==self.ID]
                experimentalData = group.groupExperimentalData[group.groupExperimentalData['Mouse ID']==int(self.ID)]
                experimentalData.reset_index(drop=True, inplace=True)
                self.experimentalData = experimentalData
    
    def get_age_wks(self,date):
        
        self.primaryData['Age(days)'] = np.empty_like(self.primaryData['Mouse ID'])
        today = pd.to_datetime(str(datetime.date.today()))
        
        for i in list(self.primaryData.index):
            dob = pd.to_datetime(str(self.primaryData['DOB'][i]))
            age_days = str(date - dob)[:-14]
            age_wks = int(age_days) / 7
            
        return age_wks
    
    
    def get_weekly_performance(self):

        m_df = self.experimentalData[['Date','Weight','Baited Arms Retrieved','Reference Memory Errors','Working Memory Errors','Video Length']]
        m_df['Date'] = pd.to_datetime(m_df['Date'])

        bins_dt = pd.date_range('2020-01-01', freq='7D', periods=100)
        bins_str = bins_dt.astype(str).values

        labels = ['({}, {}]'.format(bins_str[i-1], bins_str[i]) for i in range(1, len(bins_str))]


        m_df['cat'] = pd.cut(m_df.Date.astype(np.int64)//10**9,
                           bins=bins_dt.astype(np.int64)//10**9,
                           labels=labels)
        m_df['cat'] = m_df['cat'].cat.remove_unused_categories()
        
        m_df['Age(wks)'] = np.empty_like(m_df['Date'])
        for i in range(len(m_df['Date'])):
            m_df.loc[i,'Age(wks)'] = self.get_age_wks(m_df.loc[i,'Date'])
            
        return m_df

    
    def get_weekly_mean(self):
        
        mean_df = self.get_weekly_performance().groupby('cat').mean()
        
        return mean_df

# %%
grouping = [group1,group2,group3,group4,group5]

for m_ID in allMice:
    
    m = Mouse(grouping,m_ID)
    m.get_weekly_mean()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                              Weight  Baited Arms Retrieved  \
# cat
# (2020-01-01, 2020-01-08]  19.333333               3.666667
# (2020-01-08, 2020-01-15]  21.000000               4.000000
# (2020-01-15, 2020-01-22]  21.500000               3.000000
# (2020-01-22, 2020-01-29]  22.500000               0.500000
# (2020-01-29, 2020-02-05]  21.500000               2.000000
# (2020-02-05, 2020-02-12]  20.000000               4.000000
# (2020-02-12, 2020-02-19]  18.000000               4.000000
# (2020-02-19, 2020-02-26]  20.000000               4.000000
#
#                           Reference Memory Errors  Working Memory Errors
# cat
# (2020-01-01, 2020-01-08]                      8.0               8.666667
# (2020-01-08, 2020-01-15]                      4.0               3.000000
# (2020-01-15, 2020-01-22]                      4.5               5.500000
# (2020-01-22, 2020-01-29]                     16.0              25.500000
# (2020-01-29, 2020-02-05]                      9.0              12.500000
# (2020-02-05, 2020-02-12]                      5.0               1.500000
# (2020-02-12, 2020-02-19]                      4.0               0.000000
# (2020-02-19, 2020-02-26]                      2.0               0.000000

# %% [markdown]
# ### Explore the components

# %%
# bar plot and pie chart

# %% [markdown]
# ### Genotype Weekly Performance

# %%
#boxplot
